# %%
from matplotlib import pyplot as plt

# %%
print("input each month Total sales")
s=range(1,13)
l=list(range(12))
for i in range(0,12):
    l[i]=input("enter month sales:" )
plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.plot(s,l)
# Out:
# input each month Total sales
# enter month sales:68
# enter month sales:79
# enter month sales:24
# enter month sales:56
# enter month sales:42
# enter month sales:67
# enter month sales:25
# enter month sales:12
# enter month sales:20
# enter month sales:02
# enter month sales:09
# enter month sales:58

# %%
l=range(12)
l
# Out:
# range(0, 12)

# %%
import pandas as pd 
df=pd.read_csv("sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df["facecream"].plot(kind="box")
#df["facewash"].plot(kind="box")
#df["moisturizer"].plot(kind="box")
#df["shampoo"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.plot(df["month_number"],df["total_profit"])
plt.show()

# %%
plt.title("Company sales data of last year")
plt.xlabel("Month Number")
plt.ylabel("sold units number")
plt.plot(df["month_number"],df["total_profit"],"--",marker=".",mec="black",color="r",linewidth="3")
plt.show()

# %%
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 's')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o-r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '*-.k')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'd m')
plt.show()

# %%
ypoints = np.array([19,6,20,2])

plt.plot(ypoints, '+ c',ms="19")
plt.show()

# %%
ypoints = np.array([19,6,20,2])

plt.plot(ypoints, 'o c',ms="19",mfc="g")
plt.show()

# %%
ypoints = np.array([19,6,20,2])
zpoints = np.array([17,10,19,7])

plt.plot(ypoints, 'd:c',ms="10",mec="g")
plt.plot(zpoints, 'h-.y',ms="10",mec="k")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'Algerian','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
x = np.array([5,7,8,7,19,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = "black")

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, c = "red")

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors)

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,color="magenta", height=0.1)
plt.show()

# %%
import pandas as pd
import numpy as np
x=np.random.rand(19)
y=np.random.rand(19)
z=np.random.rand(19)
colours=np.random.rand(19)
plt.scatter(x,y,z*1000,c=z,alpha=0.75)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,19,100)
plt.hist(x)
plt.show()

# %%
l=[19,6,20,2]
plt.pie(l)
plt.show()

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
plt.title("Sales data")
plt.xlabel("Sales units in number")
plt.ylabel("Month Number")
df["facecream"].plot(marker="o")
df["facewash"].plot(marker="o")
df["shampoo"].plot(marker="o")
df["moisturizer"].plot(marker="o")
plt.legend(loc="upper left")
plt.show()

# %%
plt.scatter(df["month_number"],df["toothpaste"])
plt.title("Tooth paste sales data")
plt.xlabel("Month number")
plt.ylabel("Number of units sold")
plt.grid(linestyle="--")
plt.legend(title="Tooth paste sales data",loc="upper left")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(df["month_number"],df["facecream"],width=0.25,label="facecream sales data",align="edge")
plt.bar(df["month_number"],df["facewash"],width=-0.25,label="facewash sales data",align="edge")
plt.title("facewash and facecream sales data")
plt.xlabel("month number")
plt.ylabel("sales units in number")
plt.grid()
plt.legend(loc="upper left")
plt.show()
