# %%
import pandas as pd

# %%
df=pd.read_csv("bollywood.csv")

# %%
df.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
df.shape
# Out:
# (149, 10)

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
d=df.groupby(['Genre'])

# %%
d

# %%
d.first(149)
# Out:
#            SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# Genre
#  Drama        4       7                 0.35         42626            86
# Action       16       4                 0.09         28391             8
# Action       11      28                 6.00       2397647          3308
# Comedy        3      10                 4.00        572336           586
# Romance       1      36               104.00       8576361         26622
# Thriller     29      12                27.16      13798789         15708
# Thriller      2      10                12.00       1087320          1129
#
#            YoutubeDislikes
# Genre
#  Drama                  19
# Action                  14
# Action                 465
# Comedy                  54
# Romance               2527
# Thriller              5226
# Thriller               137

# %%
4+29+2+16+11+3+1
# Out:
# 66

# %%
df.iloc[16]
# Out:
# SlNo                          17
# Release Date           25-Jan-13
# MovieName                 Race 2
# ReleaseTime                   LW
# Genre                  Thriller
# Budget                        60
# BoxOfficeCollection          162
# YoutubeViews             7641333
# YoutubeLikes               12617
# YoutubeDislikes             2138
# Name: 16, dtype: object

# %%
d1=df.groupby(['Genre','SlNo'])

# %%
d1.first()
# Out:
#                Release Date         MovieName ReleaseTime  Budget  \
# Genre     SlNo
#  Drama    4        4-Jan-13  Rajdhani Express           N       7
#           6       30-May-14        Citylights          HS       7
#           10      11-Jan-13         Gangoobai           N       2
#           24       2-Oct-14            Haider          FS      24
#           26       8-Feb-13        Special 26           N      42
# ...                     ...               ...         ...     ...
# Thriller  141     30-Jan-15       Khamoshiyan           N      11
#           146     13-Mar-15              NH10           N      13
# Thriller  2        4-Jan-13      Table No. 21           N      10
#           17      25-Jan-13            Race 2          LW      60
#           21       1-Feb-13             David           N      10
#
#                 BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# Genre     SlNo
#  Drama    4                    0.35         42626            86
# ...

# %%
d.sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ffbae44b8ffa> in <module>
# ----> 1 d.sort_values()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
df.sort_values(by=['Genre']).value_counts()
# Out:
# SlNo  Release Date  MovieName              ReleaseTime  Genre     Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 149   23-May-14     Kochadaiiyaan          HS           Action    150     120.00               4740727       13466         2649               1
# 55    29-Mar-13     Himmatwala             N            Action    50      100.00               2501277       1             1                  1
# 53    4-Apr-14      Main Tera Hero         LW           Comedy    40      55.00                4903941       12657         2139               1
# 52    22-Mar-13     Aatma                  N            Thriller  8       8.78                 841891        997           306                1
# 51    4-Jul-14      Lekar Hum Deewana Dil  N            Romance   16      2.50                 3998331       2307          497                1
# ...

# %%
a=df["Genre"]

# %%
a

# %%
A=df['Genre'].value_counts()

# %%
A

# %%
A.sort_values(ascending=False)

# %%
A['Genre']=A.index

# %%
A

# %% [markdown]
# 1. How many records are present in the dataset? Print the metadata information of the dataset

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df.shape
# Out:
# (149, 10)

# %%
df.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %% [markdown]
# <b>2.How many movies got released in each genre? Which genre had highest number of releases? Sort
# number of releases in each genre in descending order.</b>

# %%
q=df.groupby(['Genre']).sum()

# %%
q
# Out:
#            SlNo  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# Genre
#  Drama     2597     847              2302.76      93525532        279077
# Action     1735    1308              2178.24     129290920        385154
# Action       47      59                22.10       7320673         16719
# Comedy     2640     910              1660.14      91313029        172250
# Romance    1855     629              1321.03      86882563        177241
# Thriller   2261     554               632.50      79449427        128024
# Thriller     40      80               177.65       9567923         15288
#
#            YoutubeDislikes
# Genre
#  Drama               36272
# Action               49573
# Action                2234
# Comedy               35867
# Romance              26293
# Thriller             27356
# Thriller              2370

# %%
w=df['Genre'].value_counts()

# %%
w
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Action        3
# Thriller      3
# Name: Genre, dtype: int64

# %%
w.index
# Out:
# Index(['Comedy', ' Drama ', 'Thriller', 'Romance', 'Action', 'Action ',
#        'Thriller '],
#       dtype='object')

# %%
w['Genre_category']=w.index
w['count']=df['Genre'].value_counts()

# %%
w[0]
# Out:
# 36

# %%
w.head()
# Out:
# Comedy      36
#  Drama      35
# Thriller    26
# Romance     25
# Action      21
# Name: Genre, dtype: object

# %%
pd.crosstab(df['Genre'],df['ReleaseTime'])
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
pd.crosstab(df['Genre'],df['ReleaseTime']).sum()
# Out:
# ReleaseTime
# FS    17
# HS    18
# LW    15
# N     99
# dtype: int64

# %%
import datetime

# %%
df['Release Date']=pd.to_datetime(df['Release Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %%
df['month']=df['Release Date'].apply(lambda x:x.month)
df['year']=df['Release Date'].apply(lambda x:x.year)

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
z=pd.crosstab(df['year'],df['month'])

# %%
z
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 2013       5       4         0         6        8     9     5      8    6
# 2014       6       4         2         6        7     7     5      8   12
# 2015       0       0         0         4        5     0     0      3    0
#
# month  November  October  September
# year
# 2013          5        6          5
# 2014          5        3          5
# 2015          0        0          0

# %%
z.value_counts()
# Out:
# April  August  December  February  January  July  June  March  May  November  October  September
# 6      4       2         6         7        7     5     8      12   5         3        5            1
# 5      4       0         6         8        9     5     8      6    5         6        5            1
# 0      0       0         4         5        0     0     3      0    0         0        0            1
# dtype: int64

# %% [markdown]
# Which month of the year, maximum number movie releases are seen? (Note: Extract a new column
# called month from ReleaseDate column.)

# %%
df[['month','year']]
# Out:
#         month  year
# 0       April  2014
# 1     January  2013
# 2        July  2014
# 3     January  2013
# 4        July  2014
# ..        ...   ...
# 144  February  2015
# 145     March  2015
# 146     March  2015
# 147     March  2015
# 148       May  2014
#
# [149 rows x 2 columns]

# %%
import numpy as np

# %%
pd.pivot_table(df,values=None,index=['month','year'],aggfunc=np.sum)
# Out:
#             BoxOfficeCollection  Budget  SlNo  YoutubeDislikes  YoutubeLikes  \
# month year
# 1     2013               226.50     125    83             3234         19256
#       2014               196.20     227   457             2377         13730
#       2015               250.27     154   695             8631         72612
# 2     2013               253.85     142   177             3329         27717
#       2014               183.25     184   385             5108         38946
#       2015               203.00     118   574             5414         43360
# 3     2013               212.54     133   381             1611          9642
#       2014               167.80     177   556             7301         41179
#       2015                55.99      50   441             3082         23459
# 4     2013               239.50      87   308             2428         20098
#       2014               228.00     178   451             6490         56390
# ...
