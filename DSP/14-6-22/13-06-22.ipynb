# %% [markdown]
# <h1 align="center">Markdown</h1>

# %%
import pandas as pd

# %%
data = pd.read_csv("Book1.csv")

# %%
print(data)
# Out:
#         Name  Age   Salary
# 0   Shanmukh    19  100000
# 1      Kumar    20   90000
# 2   Nagendra    18  100000
# 3          A    18  100000
# 4          A    18  100000
# 5          A    18  100000
# 6          A    18  100000
# 7          A    18  100000
# 8          A    18  100000
# 9          A    18  100000
# 10         A    18  100000
# 11         A    18  100000
# 12         A    18  100000
# 13         A    18  100000

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
l=data["Name"]

# %%
data["Name"]="name"

# %%
print(type(l))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(l)
# Out:
# 0    name
# 1    name
# 2    name
# Name: Name, dtype: object

# %%
data
# Out:
#         Name  Age   Salary
# 0   Shanmukh    19  100000
# 1      Kumar    20   90000
# 2   Nagendra    18  100000
# 3          A    18  100000
# 4          A    18  100000
# 5          A    18  100000
# 6          A    18  100000
# 7          A    18  100000
# 8          A    18  100000
# 9          A    18  100000
# 10         A    18  100000
# 11         A    18  100000
# 12         A    18  100000
# 13         A    18  100000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    14 non-null     object
#  1   Age     14 non-null     int64
#  2   Salary  14 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 464.0+ bytes

# %%
data.describe()
# Out:
#             Age          Salary
# count  14.000000      14.000000
# mean   18.214286   99285.714286
# std     0.578934    2672.612419
# min    18.000000   90000.000000
# 25%    18.000000  100000.000000
# 50%    18.000000  100000.000000
# 75%    18.000000  100000.000000
# max    20.000000  100000.000000

# %%
data[["Name","Salary"]]
# Out:
#         Name  Salary
# 0   Shanmukh  100000
# 1      Kumar   90000
# 2   Nagendra  100000
# 3          A  100000
# 4          A  100000
# 5          A  100000
# 6          A  100000
# 7          A  100000
# 8          A  100000
# 9          A  100000
# 10         A  100000
# 11         A  100000
# 12         A  100000
# 13         A  100000

# %%
data[1:6]
# Out:
#        Name  Age   Salary
# 1     Kumar    20   90000
# 2  Nagendra    18  100000
# 3         A    18  100000
# 4         A    18  100000
# 5         A    18  100000

# %%
data1=pd.read_csv("excel.csv",head="none")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9e35d0d8bd3b> in <module>
# ----> 1 data1=pd.read_csv("excel.csv",head="none")
#
# TypeError: read_csv() got an unexpected keyword argument 'head'

# %%
data1
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5]
# Index: []

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       0 non-null      object
#  1   2       0 non-null      object
#  2   3       0 non-null      object
#  3   4       0 non-null      object
#  4   5       0 non-null      object
# dtypes: object(5)
# memory usage: 0.0+ bytes

# %%
f=pd.read_csv("mini.csv")
f
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      R  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      R  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      R  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      R  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      R  Number
# ...                ...      ...         ...        ...    ...     ...
# 19862    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 19863    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 19864    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 19865    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 19866    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
c=pd.read_csv("excel.csv")
c
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Attrition                 1000 non-null   object
#  2   BusinessTravel            1000 non-null   object
#  3   DailyRate                 1000 non-null   int64
#  4   Department                1000 non-null   object
#  5   DistanceFromHome          1000 non-null   int64
#  6   Education                 1000 non-null   int64
#  7   EducationField            1000 non-null   object
#  8   EmployeeCount             1000 non-null   int64
#  9   EmployeeNumber            1000 non-null   int64
#  10  EnvironmentSatisfaction   1000 non-null   int64
#  11  Gender                    1000 non-null   object
#  12  HourlyRate                1000 non-null   int64
#  13  JobInvolvement            1000 non-null   int64
# ...

# %%
c.describe()
# Out:
#                Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  1000.000000  1000.000000       1000.000000  1000.00000         1000.0
# mean     38.487000   835.616000         25.455000     3.04100            1.0
# std      12.610268   401.419232         14.762585     1.41468            0.0
# min      18.000000   100.000000          1.000000     1.00000            1.0
# 25%      28.000000   508.500000         13.000000     2.00000            1.0
# 50%      38.000000   863.500000         25.000000     3.00000            1.0
# 75%      50.000000  1176.000000         39.000000     4.00000            1.0
# max      60.000000  1499.000000         50.000000     5.00000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1000.000000              1000.000000  1000.000000     1000.000000
# mean       500.500000                 2.512000   112.537000        2.500000
# ...

# %%
c.min()
# Out:
# Age                                      18
# Attrition                                No
# BusinessTravel                   Non-Travel
# DailyRate                               100
# Department                         Hardware
# DistanceFromHome                          1
# Education                                 1
# EducationField              Human Resources
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   1
# Gender                               Female
# HourlyRate                               30
# JobInvolvement                            1
# JobLevel                                  1
# JobRole                           Developer
# JobSatisfaction                           1
# MaritalStatus                      Divorced
# MonthlyIncome                          1090
# MonthlyRate                            2289
# NumCompaniesWorked                        0
# ...

# %%
c.max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1499
# Department                               Support
# DistanceFromHome                              50
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                              1000
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   200
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              50924
# ...

# %%
c.sum()
# Out:
# Age                                                                     38487
# Attrition                   NoYesYesNoYesYesNoNoNoNoNoYesYesYesYesNoYesNoY...
# BusinessTravel              Travel_FrequentlyNon-TravelNon-TravelTravel_Fr...
# DailyRate                                                              835616
# Department                  SupportHuman ResourcesResearch & DevelopmentSu...
# DistanceFromHome                                                        25455
# Education                                                                3041
# EducationField              OtherOtherLife SciencesTechnical DegreeMedical...
# EmployeeCount                                                            1000
# EmployeeNumber                                                         500500
# EnvironmentSatisfaction                                                  2512
# Gender                      FemaleFemaleMaleMaleMaleMaleFemaleFemaleFemale...
# ...

# %%
c.count()
# Out:
# Age                         1000
# Attrition                   1000
# BusinessTravel              1000
# DailyRate                   1000
# Department                  1000
# DistanceFromHome            1000
# Education                   1000
# EducationField              1000
# EmployeeCount               1000
# EmployeeNumber              1000
# EnvironmentSatisfaction     1000
# Gender                      1000
# HourlyRate                  1000
# JobInvolvement              1000
# JobLevel                    1000
# JobRole                     1000
# JobSatisfaction             1000
# MaritalStatus               1000
# MonthlyIncome               1000
# MonthlyRate                 1000
# NumCompaniesWorked          1000
# Over18                      1000
# OverTime                    1000
# PercentSalaryHike           1000
# PerformanceRating           1000
# RelationshipSatisfaction    1000
# StandardHours               1000
# StockOptionLevel            1000
# ...

# %%
c.tail(19)
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 981   56        No         Non-Travel        566  Research & Development
# 982   55       Yes         Non-Travel        361  Research & Development
# 983   40       Yes         Non-Travel        861  Research & Development
# 984   22       Yes         Non-Travel        767                Software
# 985   58       Yes  Travel_Frequently        436                Hardware
# 986   33       Yes      Travel_Rarely        799         Human Resources
# 987   24       Yes         Non-Travel        440                   Sales
# 988   29        No      Travel_Rarely       1125                 Support
# 989   25       Yes         Non-Travel        124                Software
# 990   32       Yes  Travel_Frequently        981                   Sales
# 991   20        No      Travel_Rarely        530         Human Resources
# 992   58       Yes      Travel_Rarely        596         Human Resources
# ...

# %%
c.head(19)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    31        No  Travel_Frequently        836                 Support
# 1    43       Yes         Non-Travel       1071         Human Resources
# 2    25       Yes         Non-Travel       1374  Research & Development
# 3    29        No  Travel_Frequently       1415                 Support
# 4    20       Yes      Travel_Rarely       1076         Human Resources
# 5    46       Yes  Travel_Frequently       1176         Human Resources
# 6    52        No         Non-Travel       1311                 Support
# 7    18        No      Travel_Rarely        319         Human Resources
# 8    41        No         Non-Travel       1074                   Sales
# 9    44        No      Travel_Rarely        119                Hardware
# 10   34        No         Non-Travel        775                 Support
# 11   55       Yes  Travel_Frequently       1233                 Support
# ...

# %%
c.isnull()
# Out:
#        Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0    False      False           False      False       False
# 1    False      False           False      False       False
# 2    False      False           False      False       False
# 3    False      False           False      False       False
# 4    False      False           False      False       False
# ..     ...        ...             ...        ...         ...
# 995  False      False           False      False       False
# 996  False      False           False      False       False
# 997  False      False           False      False       False
# 998  False      False           False      False       False
# 999  False      False           False      False       False
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0               False      False           False          False
# 1               False      False           False          False
# ...

# %%
c.notnull()
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    True       True            True       True        True              True
# 1    True       True            True       True        True              True
# 2    True       True            True       True        True              True
# 3    True       True            True       True        True              True
# 4    True       True            True       True        True              True
# ..    ...        ...             ...        ...         ...               ...
# 995  True       True            True       True        True              True
# 996  True       True            True       True        True              True
# 997  True       True            True       True        True              True
# 998  True       True            True       True        True              True
# 999  True       True            True       True        True              True
#
# ...
