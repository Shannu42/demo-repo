# %% [markdown]
# <h1 align="center", style="color:BLUE">DATA CLEANING</h1>

# %%
import pandas as pd
z=pd.read_csv("csv_file.csv")

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    14 non-null     object
#  1   Age     14 non-null     int64
#  2   Salary  14 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 464.0+ bytes

# %%
z.describe()
# Out:
#             Age          Salary
# count  14.000000      14.000000
# mean   18.214286   99285.714286
# std     0.578934    2672.612419
# min    18.000000   90000.000000
# 25%    18.000000  100000.000000
# 50%    18.000000  100000.000000
# 75%    18.000000  100000.000000
# max    20.000000  100000.000000

# %%
z.head()
# Out:
#        Name  Age   Salary
# 0  Shanmukh    19  100000
# 1     Kumar    20   90000
# 2  Nagendra    18  100000
# 3         A    18  100000
# 4         A    18  100000

# %%
z.tail()
# Out:
#    Name  Age   Salary
# 9     A    18  100000
# 10    A    18  100000
# 11    A    18  100000
# 12    A    18  100000
# 13    A    18  100000

# %%
z.tail(7)
# Out:
#    Name  Age   Salary
# 7     A    18  100000
# 8     A    18  100000
# 9     A    18  100000
# 10    A    18  100000
# 11    A    18  100000
# 12    A    18  100000
# 13    A    18  100000

# %%
z.shape
# Out:
# (14, 3)

# %%
z["Name"].head()
# Out:
# 0    Shanmukh
# 1       Kumar
# 2    Nagendra
# 3           A
# 4           A
# Name: Name, dtype: object

# %%
z.columns
# Out:
# Index(['Name', 'Age ', 'Salary'], dtype='object')

# %%
z=z.rename(columns={"Age ":"age"})

# %%
z["age"].tail()
# Out:
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# Name: age, dtype: int64

# %% [markdown]
# <h1 align="center">Reading Excel Files</h1>

# %%
y=pd.read_excel("excel_records.xlsx")

# %%
y.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   31        No  Travel_Frequently        836                 Support
# 1   43       Yes         Non-Travel       1071         Human Resources
# 2   25       Yes         Non-Travel       1374  Research & Development
# 3   29        No  Travel_Frequently       1415                 Support
# 4   20       Yes      Travel_Rarely       1076         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                16          5             Other              1
# 1                14          3             Other              1
# 2                 3          5     Life Sciences              1
# 3                30          2  Technical Degree              1
# 4                19          3           Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         3            80
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Attrition                 1000 non-null   object
#  2   BusinessTravel            1000 non-null   object
#  3   DailyRate                 1000 non-null   int64
#  4   Department                1000 non-null   object
#  5   DistanceFromHome          1000 non-null   int64
#  6   Education                 1000 non-null   int64
#  7   EducationField            1000 non-null   object
#  8   EmployeeCount             1000 non-null   int64
#  9   EmployeeNumber            1000 non-null   int64
#  10  EnvironmentSatisfaction   1000 non-null   int64
#  11  Gender                    1000 non-null   object
#  12  HourlyRate                1000 non-null   int64
#  13  JobInvolvement            1000 non-null   int64
# ...

# %%
y.describe()
# Out:
#                Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  1000.000000  1000.000000       1000.000000  1000.00000         1000.0
# mean     38.487000   835.616000         25.455000     3.04100            1.0
# std      12.610268   401.419232         14.762585     1.41468            0.0
# min      18.000000   100.000000          1.000000     1.00000            1.0
# 25%      28.000000   508.500000         13.000000     2.00000            1.0
# 50%      38.000000   863.500000         25.000000     3.00000            1.0
# 75%      50.000000  1176.000000         39.000000     4.00000            1.0
# max      60.000000  1499.000000         50.000000     5.00000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1000.000000              1000.000000  1000.000000     1000.000000
# mean       500.500000                 2.512000   112.537000        2.500000
# ...

# %%
y.tail()
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 995   49        No         Non-Travel       1465    Support                28
# 996   24       Yes  Travel_Frequently        387      Sales                45
# 997   45       Yes      Travel_Rarely       1304   Software                 7
# 998   39        No         Non-Travel        217   Hardware                39
# 999   19       Yes  Travel_Frequently       1447   Hardware                 6
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  ...  \
# 995          3   Human Resources              1             996  ...
# 996          3  Technical Degree              1             997  ...
# 997          5             Other              1             998  ...
# 998          4   Human Resources              1             999  ...
# 999          5     Life Sciences              1            1000  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
y.drop(columns=["TotalWorkingYears","TrainingTimesLastYear","WorkLifeBalance","YearsAtCompany","YearsInCurrentRole","YearsSinceLastPromotion","YearsWithCurrManager"],inplace=True)

# %%
y.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   31        No  Travel_Frequently        836                 Support
# 1   43       Yes         Non-Travel       1071         Human Resources
# 2   25       Yes         Non-Travel       1374  Research & Development
# 3   29        No  Travel_Frequently       1415                 Support
# 4   20       Yes      Travel_Rarely       1076         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                16          5             Other              1
# 1                14          3             Other              1
# 2                 3          5     Life Sciences              1
# 3                30          2  Technical Degree              1
# 4                19          3           Medical              1
#
#    EmployeeNumber  ...  MonthlyIncome MonthlyRate  NumCompaniesWorked  Over18  \
# ...

# %%
y.to_csv("ready.csv")

# %% [markdown]
# <h1 align="center">Reading SQL Files</h1>

# %%
import sqlite3

# %%
conn=sqlite3.connect("xyz.db")

# %%
cur=conn.cursor()

# %%
cur.execute("tables;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-24-39249ca08002> in <module>
# ----> 1 cur.execute("tables;")
#
# OperationalError: near "tables": syntax error
